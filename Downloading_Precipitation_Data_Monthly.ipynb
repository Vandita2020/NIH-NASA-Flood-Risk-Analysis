# %% [markdown]
# # Downloading Monthly Precipitation Data
#
# In this notebook, we will use a **urls** file that contains a list of URLs for monthly precipitation data to download all relevant data and then filter it for the respective state.

# %% [markdown]
# ## Import libraries
#
# We import a number of libraries which we will use to read netCDF files, filter data based on a given state and then, output the result as a CSV file.

# %%
# Uncomment and run the following if working on Google Colab to install required libraries

# !pip install geopandas netCDF4 shapely rtree pygeos
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/d7/bf/e9cefb69d39155d122b6ddca53893b61535fa6ffdad70bf5ef708977f53f/geopandas-0.9.0-py2.py3-none-any.whl (994kB)
#      |████████████████████████████████| 1.0MB 8.9MB/s
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/37/56/f65978898fb8e7e5df9c67531d86eb24eb04938deae3b61dbcce12c98212/netCDF4-1.5.6-cp37-cp37m-manylinux2014_x86_64.whl (4.7MB)
#      |████████████████████████████████| 4.7MB 30.6MB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.7/dist-packages (1.7.1)
# Collecting rtree
#   Downloading https://files.pythonhosted.org/packages/51/05/5a67111cee91d2165a2bcb855f442186e3d76ddef834596cc84d4875c401/Rtree-0.9.7-cp37-cp37m-manylinux2010_x86_64.whl (994kB)
#      |████████████████████████████████| 1.0MB 34.0MB/s
# Collecting pygeos
#   Downloading https://files.pythonhosted.org/packages/f5/2c/071f928a67d8a7e754a99ba3281ec685c8dfa4d64f9b83fc53ca2c325b82/pygeos-0.9-cp37-cp37m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 44.3MB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/b1/72/d52e9ca81caef056062d71991b0e9b1d16af042245627c5d0e4916a36c4f/pyproj-3.0.1-cp37-cp37m-manylinux2010_x86_64.whl (6.5MB)
#      |████████████████████████████████| 6.5MB 42.8MB/s
# Collecting fiona>=1.8
#   Downloading https://files.pythonhosted.org/packages/47/c2/67d1d0acbaaee3b03e5e22e3b96c33219cb5dd392531c9ff9cee7c2eb3e4/Fiona-1.8.18-cp37-cp37m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 257kB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.7/dist-packages (from netCDF4) (1.19.5)
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/41/e0/3e120cca16571c5ee3b35f1ed432c2aae5dc91e2b789e8b9c3a70e721ea0/cftime-1.4.1-cp37-cp37m-manylinux2014_x86_64.whl (313kB)
#      |████████████████████████████████| 317kB 46.9MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->geopandas) (2020.12.5)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (20.3.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Installing collected packages: pyproj, cligj, munch, click-plugins, fiona, geopandas, cftime, netCDF4, rtree, pygeos
# Successfully installed cftime-1.4.1 click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 geopandas-0.9.0 munch-2.5.0 netCDF4-1.5.6 pygeos-0.9 pyproj-3.0.1 rtree-0.9.7

# %%
import os
import json
import requests
import descartes
import numpy as np
import pandas as pd
import geopandas as gpd
from netCDF4 import Dataset
import urllib.request as urllib2
from geopandas.tools import sjoin
from urllib.parse import urlencode
from http.cookiejar import CookieJar
from shapely.geometry import Point, Polygon, shape
# Out:
# /usr/local/lib/python3.7/dist-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# ## Load credentials and initiate cookies
#
# We read credentials from a file **credentials.json** provided by the user.

# %%
# Open credentials file
# credentials_file = open("credentials.json")

# Load credentials
# credentials = json.load(credentials_file)
username = "Vandita"
password = "2xKXd#?qt.AkN8Z"
  
# Close the file
# credentials_file.close()

# %% [markdown]
# We then use these credentials to set up cookies and a method we will use to request data from [GES DSIC](https://disc.gsfc.nasa.gov/). The following code is based on the instructions provided by the [EarthData Wiki](https://wiki.earthdata.nasa.gov/display/EL/How+To+Access+Data+With+Python).

# %%
# Set up a password manager
password_manager = urllib2.HTTPPasswordMgrWithDefaultRealm()
password_manager.add_password(None, "https://urs.earthdata.nasa.gov", username, password)

# Create a CookieJar for managing cookies to be used within a session
# and avoid requiring re-login
cookie_jar = CookieJar()

# Build and use opener
opener = urllib2.build_opener(
    urllib2.HTTPBasicAuthHandler(password_manager),
    urllib2.HTTPCookieProcessor(cookie_jar))
urllib2.install_opener(opener)

# %% [markdown]
# ## Import data files
#
# We will load in the shape file for USA and based on the state we are looking at, we will filter the data. We take the URLs saved in the file **GPM_USA_monthly_urls.txt** which contains the urls for monthly GPM data.

# %%
shape_file = gpd.read_file("cb_2018_us_state_500k.shp")

# %% [markdown]
# ## Create csv
#
# I have created a function which takes in the urls file and creates CSV file for the respective state.

# %%
def create_csv(url_file_path, shape_file, state_code):
    
    # Open URLs file for the given state
    url_file = open(url_file_path, "r")
    
    # Filter shape file for the specific state
    shape_file = shape_file[shape_file["STUSPS"] == state_code].reset_index(drop = True)
    
    # Create a dataframe which will store all data
    resultant_data = pd.DataFrame({"Latitude": [], 
                                   "Longitude": [], 
                                   "Precipitation": [], 
                                   "geometry": []})
    
    
    # For each URL, get the data
    for URL in url_file:

        # Make sure the URL is not for a PDF file
        if URL[-4:] != "pdf\n":
            
            # Get data from the URL
            request = urllib2.Request(URL[:-1])
            response = urllib2.urlopen(request)
            result = response.read()

            # Save the retrieved data to a file
            FILENAME = URL.split("https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGM.06/")[1].split("/")[1].split("?")[0]
            f = open(FILENAME, 'wb')
            f.write(result)
            f.close()

            # Read data
            data = Dataset(FILENAME)
            
            # Get latitude, longitude and precipitation
            lon_values = list(np.repeat(data['lon'][:], data['lat'][:].shape[0]))
            lat_values = list(np.tile(data['lat'][:], data['lon'][:].shape[0]))
            precp_values = data['precipitation'][:][0].flatten()
            temp_df = pd.DataFrame({"Latitude": lat_values, "Longitude": lon_values, "Precipitation": precp_values})

            # Create geodataframe from the points
            geometry = [Point(xy) for xy in zip(temp_df["Longitude"], temp_df["Latitude"])]
            points = gpd.GeoDataFrame(temp_df, crs = "EPSG:4269", geometry = geometry)

            # Select the data that lies within the given state
            final_df = sjoin(points, shape_file, how = 'inner', op = 'intersects')
            
            # Create dataframe for the given file
            final_df = final_df[["Latitude", "Longitude", "Precipitation", "geometry"]].reset_index(drop = True)
            date = data.__dict__["FileHeader"].split("\nStartGranuleDateTime=")[1].split(";")[0].split("T")[0].split("-")
            final_df["Year"] = date[0]
            final_df["Month"] = date[1]

            # Append to the resultant dataframe
            resultant_data = pd.concat([resultant_data, final_df], ignore_index = True)

            # Print to console that a record has been updated
            print("Retrieved data for {}, {}".format(date[1], date[0]))

            # Remove the file we created as we no longer need
            os.remove(FILENAME)

    # Save the final dataframe to the system
    resultant_data.to_csv(state_code + "_monthly.csv", index = False)

# %% [markdown]
# ## Retrieve data
#
# The above function can now be called with the two-letter code for which the CSV needs to be created.

# %%
create_csv("url.txt", shape_file, state_code = "FL")
# Out:
# Retrieved data for 01, 2010
# Retrieved data for 02, 2010
# Retrieved data for 03, 2010
# Retrieved data for 04, 2010
# Retrieved data for 05, 2010
# Retrieved data for 06, 2010
# Retrieved data for 07, 2010
# Retrieved data for 08, 2010
# Retrieved data for 09, 2010
# Retrieved data for 10, 2010
# Retrieved data for 11, 2010
# Retrieved data for 12, 2010
# Retrieved data for 01, 2011
# Retrieved data for 02, 2011
# Retrieved data for 03, 2011
# Retrieved data for 04, 2011
# Retrieved data for 05, 2011
# Retrieved data for 06, 2011
# Retrieved data for 07, 2011
# Retrieved data for 08, 2011
# Retrieved data for 09, 2011
# Retrieved data for 10, 2011
# Retrieved data for 11, 2011
# Retrieved data for 12, 2011
# Retrieved data for 01, 2012
# Retrieved data for 02, 2012
# Retrieved data for 03, 2012
# Retrieved data for 04, 2012
# Retrieved data for 05, 2012
# Retrieved data for 06, 2012
# Retrieved data for 07, 2012
# Retrieved data for 08, 2012
# Retrieved data for 09, 2012
# Retrieved data for 10, 2012
# Retrieved data for 11, 2012
# Retrieved data for 12, 2012
# Retrieved data for 01, 2013
# Retrieved data for 02, 2013
# Retrieved data for 03, 2013
# Retrieved data for 04, 2013
# Retrieved data for 05, 2013
# Retrieved data for 06, 2013
# Retrieved data for 07, 2013
# Retrieved data for 08, 2013
# Retrieved data for 09, 2013
# Retrieved data for 10, 2013
# Retrieved data for 11, 2013
# Retrieved data for 12, 2013
# Retrieved data for 01, 2014
# Retrieved data for 02, 2014
# Retrieved data for 03, 2014
# Retrieved data for 04, 2014
# Retrieved data for 05, 2014
# Retrieved data for 06, 2014
# Retrieved data for 07, 2014
# Retrieved data for 08, 2014
# Retrieved data for 09, 2014
# Retrieved data for 10, 2014
# Retrieved data for 11, 2014
# Retrieved data for 12, 2014
# Retrieved data for 01, 2015
# Retrieved data for 02, 2015
# Retrieved data for 03, 2015
# Retrieved data for 04, 2015
# Retrieved data for 05, 2015
# Retrieved data for 06, 2015
# Retrieved data for 07, 2015
# Retrieved data for 08, 2015
# Retrieved data for 09, 2015
# Retrieved data for 10, 2015
# Retrieved data for 11, 2015
# Retrieved data for 12, 2015
# Retrieved data for 01, 2016
# Retrieved data for 02, 2016
# Retrieved data for 03, 2016
# Retrieved data for 04, 2016
# Retrieved data for 05, 2016
# Retrieved data for 06, 2016
# Retrieved data for 07, 2016
# Retrieved data for 08, 2016
# Retrieved data for 09, 2016
# Retrieved data for 10, 2016
# Retrieved data for 11, 2016
# Retrieved data for 12, 2016
# Retrieved data for 01, 2017
# Retrieved data for 02, 2017
# Retrieved data for 03, 2017
# Retrieved data for 04, 2017
# Retrieved data for 05, 2017
# Retrieved data for 06, 2017
# Retrieved data for 07, 2017
# Retrieved data for 08, 2017
# Retrieved data for 09, 2017
# Retrieved data for 10, 2017
# Retrieved data for 11, 2017
# Retrieved data for 12, 2017
# Retrieved data for 01, 2018
# Retrieved data for 02, 2018
# Retrieved data for 03, 2018
# Retrieved data for 04, 2018
# Retrieved data for 05, 2018
# Retrieved data for 06, 2018
# Retrieved data for 07, 2018
# Retrieved data for 08, 2018
# Retrieved data for 09, 2018
# Retrieved data for 10, 2018
# Retrieved data for 11, 2018
# Retrieved data for 12, 2018
# Retrieved data for 01, 2019
# Retrieved data for 02, 2019
# Retrieved data for 03, 2019
# Retrieved data for 04, 2019
# Retrieved data for 05, 2019
# Retrieved data for 06, 2019
# Retrieved data for 07, 2019
# Retrieved data for 08, 2019
# Retrieved data for 09, 2019
# Retrieved data for 10, 2019
# Retrieved data for 11, 2019
# Retrieved data for 12, 2019
# Retrieved data for 01, 2020
# Retrieved data for 02, 2020
# Retrieved data for 03, 2020
# Retrieved data for 04, 2020
# Retrieved data for 05, 2020
# Retrieved data for 06, 2020
# Retrieved data for 07, 2020
# Retrieved data for 08, 2020
# Retrieved data for 09, 2020
# Retrieved data for 10, 2020
# Retrieved data for 11, 2020
# Retrieved data for 12, 2020

# %%
create_csv("url2.txt", shape_file, state_code = "AR")
# Out:
# Retrieved data for 01, 2010
# Retrieved data for 02, 2010
# Retrieved data for 03, 2010
# Retrieved data for 04, 2010
# Retrieved data for 05, 2010
# Retrieved data for 06, 2010
# Retrieved data for 07, 2010
# Retrieved data for 08, 2010
# Retrieved data for 09, 2010
# Retrieved data for 10, 2010
# Retrieved data for 11, 2010
# Retrieved data for 12, 2010
# Retrieved data for 01, 2011
# Retrieved data for 02, 2011
# Retrieved data for 03, 2011
# Retrieved data for 04, 2011
# Retrieved data for 05, 2011
# Retrieved data for 06, 2011
# Retrieved data for 07, 2011
# Retrieved data for 08, 2011
# Retrieved data for 09, 2011
# Retrieved data for 10, 2011
# Retrieved data for 11, 2011
# Retrieved data for 12, 2011
# Retrieved data for 01, 2012
# Retrieved data for 02, 2012
# Retrieved data for 03, 2012
# Retrieved data for 04, 2012
# Retrieved data for 05, 2012
# Retrieved data for 06, 2012
# Retrieved data for 07, 2012
# Retrieved data for 08, 2012
# Retrieved data for 09, 2012
# Retrieved data for 10, 2012
# Retrieved data for 11, 2012
# Retrieved data for 12, 2012
# Retrieved data for 01, 2013
# Retrieved data for 02, 2013
# Retrieved data for 03, 2013
# Retrieved data for 04, 2013
# Retrieved data for 05, 2013
# Retrieved data for 06, 2013
# Retrieved data for 07, 2013
# Retrieved data for 08, 2013
# Retrieved data for 09, 2013
# Retrieved data for 10, 2013
# Retrieved data for 11, 2013
# Retrieved data for 12, 2013
# Retrieved data for 01, 2014
# Retrieved data for 02, 2014
# Retrieved data for 03, 2014
# Retrieved data for 04, 2014
# Retrieved data for 05, 2014
# Retrieved data for 06, 2014
# Retrieved data for 07, 2014
# Retrieved data for 08, 2014
# Retrieved data for 09, 2014
# Retrieved data for 10, 2014
# Retrieved data for 11, 2014
# Retrieved data for 12, 2014
# Retrieved data for 01, 2015
# Retrieved data for 02, 2015
# Retrieved data for 03, 2015
# Retrieved data for 04, 2015
# Retrieved data for 05, 2015
# Retrieved data for 06, 2015
# Retrieved data for 07, 2015
# Retrieved data for 08, 2015
# Retrieved data for 09, 2015
# Retrieved data for 10, 2015
# Retrieved data for 11, 2015
# Retrieved data for 12, 2015
# Retrieved data for 01, 2016
# Retrieved data for 02, 2016
# Retrieved data for 03, 2016
# Retrieved data for 04, 2016
# Retrieved data for 05, 2016
# Retrieved data for 06, 2016
# Retrieved data for 07, 2016
# Retrieved data for 08, 2016
# Retrieved data for 09, 2016
# Retrieved data for 10, 2016
# Retrieved data for 11, 2016
# Retrieved data for 12, 2016
# Retrieved data for 01, 2017
# Retrieved data for 02, 2017
# Retrieved data for 03, 2017
# Retrieved data for 04, 2017
# Retrieved data for 05, 2017
# Retrieved data for 06, 2017
# Retrieved data for 07, 2017
# Retrieved data for 08, 2017
# Retrieved data for 09, 2017
# Retrieved data for 10, 2017
# Retrieved data for 11, 2017
# Retrieved data for 12, 2017
# Retrieved data for 01, 2018
# Retrieved data for 02, 2018
# Retrieved data for 03, 2018
# Retrieved data for 04, 2018
# Retrieved data for 05, 2018
# Retrieved data for 06, 2018
# Retrieved data for 07, 2018
# Retrieved data for 08, 2018
# Retrieved data for 09, 2018
# Retrieved data for 10, 2018
# Retrieved data for 11, 2018
# Retrieved data for 12, 2018
# Retrieved data for 01, 2019
# Retrieved data for 02, 2019
# Retrieved data for 03, 2019
# Retrieved data for 04, 2019
# Retrieved data for 05, 2019
# Retrieved data for 06, 2019
# Retrieved data for 07, 2019
# Retrieved data for 08, 2019
# Retrieved data for 09, 2019
# Retrieved data for 10, 2019
# Retrieved data for 11, 2019
# Retrieved data for 12, 2019
# Retrieved data for 01, 2020
# Retrieved data for 02, 2020
# Retrieved data for 03, 2020
# Retrieved data for 04, 2020
# Retrieved data for 05, 2020
# Retrieved data for 06, 2020
# Retrieved data for 07, 2020
# Retrieved data for 08, 2020
# Retrieved data for 09, 2020
# Retrieved data for 10, 2020
# Retrieved data for 11, 2020
# Retrieved data for 12, 2020

# %%
# create_csv("precipitation_data/monthly/OK_monthly_urls.txt", shape_file, state_code = "OK")
# Out:
# Retrieved data for 06, 2000
# Retrieved data for 07, 2000
# Retrieved data for 08, 2000
# Retrieved data for 09, 2000
# Retrieved data for 10, 2000
# Retrieved data for 11, 2000
# Retrieved data for 12, 2000
# Retrieved data for 01, 2001
# Retrieved data for 02, 2001
# Retrieved data for 03, 2001
# Retrieved data for 04, 2001
# Retrieved data for 05, 2001
# Retrieved data for 06, 2001
# Retrieved data for 07, 2001
# Retrieved data for 08, 2001
# Retrieved data for 09, 2001
# Retrieved data for 10, 2001
# Retrieved data for 11, 2001
# Retrieved data for 12, 2001
# Retrieved data for 01, 2002
# Retrieved data for 02, 2002
# Retrieved data for 03, 2002
# Retrieved data for 04, 2002
# Retrieved data for 05, 2002
# Retrieved data for 06, 2002
# Retrieved data for 07, 2002
# Retrieved data for 08, 2002
# Retrieved data for 09, 2002
# Retrieved data for 10, 2002
# Retrieved data for 11, 2002
# Retrieved data for 12, 2002
# Retrieved data for 01, 2003
# Retrieved data for 02, 2003
# Retrieved data for 03, 2003
# Retrieved data for 04, 2003
# Retrieved data for 05, 2003
# Retrieved data for 06, 2003
# Retrieved data for 07, 2003
# Retrieved data for 08, 2003
# Retrieved data for 09, 2003
# Retrieved data for 10, 2003
# Retrieved data for 11, 2003
# Retrieved data for 12, 2003
# Retrieved data for 01, 2004
# Retrieved data for 02, 2004
# Retrieved data for 03, 2004
# Retrieved data for 04, 2004
# Retrieved data for 05, 2004
# Retrieved data for 06, 2004
# Retrieved data for 07, 2004
# Retrieved data for 08, 2004
# Retrieved data for 09, 2004
# Retrieved data for 10, 2004
# Retrieved data for 11, 2004
# Retrieved data for 12, 2004
# Retrieved data for 01, 2005
# Retrieved data for 02, 2005
# Retrieved data for 03, 2005
# Retrieved data for 04, 2005
# Retrieved data for 05, 2005
# Retrieved data for 06, 2005
# Retrieved data for 07, 2005
# Retrieved data for 08, 2005
# Retrieved data for 09, 2005
# Retrieved data for 10, 2005
# Retrieved data for 11, 2005
# Retrieved data for 12, 2005
# Retrieved data for 01, 2006
# Retrieved data for 02, 2006
# Retrieved data for 03, 2006
# Retrieved data for 04, 2006
# Retrieved data for 05, 2006
# Retrieved data for 06, 2006
# Retrieved data for 07, 2006
# Retrieved data for 08, 2006
# Retrieved data for 09, 2006
# Retrieved data for 10, 2006
# Retrieved data for 11, 2006
# Retrieved data for 12, 2006
# Retrieved data for 01, 2007
# Retrieved data for 02, 2007
# Retrieved data for 03, 2007
# Retrieved data for 04, 2007
# Retrieved data for 05, 2007
# Retrieved data for 06, 2007
# Retrieved data for 07, 2007
# Retrieved data for 08, 2007
# Retrieved data for 09, 2007
# Retrieved data for 10, 2007
# Retrieved data for 11, 2007
# Retrieved data for 12, 2007
# Retrieved data for 01, 2008
# Retrieved data for 02, 2008
# Retrieved data for 03, 2008
# Retrieved data for 04, 2008
# Retrieved data for 05, 2008
# Retrieved data for 06, 2008
# Retrieved data for 07, 2008
# Retrieved data for 08, 2008
# Retrieved data for 09, 2008
# Retrieved data for 10, 2008
# Retrieved data for 11, 2008
# Retrieved data for 12, 2008
# Retrieved data for 01, 2009
# Retrieved data for 02, 2009
# Retrieved data for 03, 2009
# Retrieved data for 04, 2009
# Retrieved data for 05, 2009
# Retrieved data for 06, 2009
# Retrieved data for 07, 2009
# Retrieved data for 08, 2009
# Retrieved data for 09, 2009
# Retrieved data for 10, 2009
# Retrieved data for 11, 2009
# Retrieved data for 12, 2009
# Retrieved data for 01, 2010
# Retrieved data for 02, 2010
# Retrieved data for 03, 2010
# Retrieved data for 04, 2010
# Retrieved data for 05, 2010
# Retrieved data for 06, 2010
# Retrieved data for 07, 2010
# Retrieved data for 08, 2010
# Retrieved data for 09, 2010
# Retrieved data for 10, 2010
# Retrieved data for 11, 2010
# Retrieved data for 12, 2010
# Retrieved data for 01, 2011
# Retrieved data for 02, 2011
# Retrieved data for 03, 2011
# Retrieved data for 04, 2011
# Retrieved data for 05, 2011
# Retrieved data for 06, 2011
# Retrieved data for 07, 2011
# Retrieved data for 08, 2011
# Retrieved data for 09, 2011
# Retrieved data for 10, 2011
# Retrieved data for 11, 2011
# Retrieved data for 12, 2011
# Retrieved data for 01, 2012
# Retrieved data for 02, 2012
# Retrieved data for 03, 2012
# Retrieved data for 04, 2012
# Retrieved data for 05, 2012
# Retrieved data for 06, 2012
# Retrieved data for 07, 2012
# Retrieved data for 08, 2012
# Retrieved data for 09, 2012
# Retrieved data for 10, 2012
# Retrieved data for 11, 2012
# Retrieved data for 12, 2012
# Retrieved data for 01, 2013
# Retrieved data for 02, 2013
# Retrieved data for 03, 2013
# Retrieved data for 04, 2013
# Retrieved data for 05, 2013
# Retrieved data for 06, 2013
# Retrieved data for 07, 2013
# Retrieved data for 08, 2013
# Retrieved data for 09, 2013
# Retrieved data for 10, 2013
# Retrieved data for 11, 2013
# Retrieved data for 12, 2013
# Retrieved data for 01, 2014
# Retrieved data for 02, 2014
# Retrieved data for 03, 2014
# Retrieved data for 04, 2014
# Retrieved data for 05, 2014
# Retrieved data for 06, 2014
# Retrieved data for 07, 2014
# Retrieved data for 08, 2014
# Retrieved data for 09, 2014
# Retrieved data for 10, 2014
# Retrieved data for 11, 2014
# Retrieved data for 12, 2014
# Retrieved data for 01, 2015
# Retrieved data for 02, 2015
# Retrieved data for 03, 2015
# Retrieved data for 04, 2015
# Retrieved data for 05, 2015
# Retrieved data for 06, 2015
# Retrieved data for 07, 2015
# Retrieved data for 08, 2015
# Retrieved data for 09, 2015
# Retrieved data for 10, 2015
# Retrieved data for 11, 2015
# Retrieved data for 12, 2015
# Retrieved data for 01, 2016
# Retrieved data for 02, 2016
# Retrieved data for 03, 2016
# Retrieved data for 04, 2016
# Retrieved data for 05, 2016
# Retrieved data for 06, 2016
# Retrieved data for 07, 2016
# Retrieved data for 08, 2016
# Retrieved data for 09, 2016
# Retrieved data for 10, 2016
# Retrieved data for 11, 2016
# Retrieved data for 12, 2016
# Retrieved data for 01, 2017
# Retrieved data for 02, 2017
# Retrieved data for 03, 2017
# Retrieved data for 04, 2017
# Retrieved data for 05, 2017
# Retrieved data for 06, 2017
# Retrieved data for 07, 2017
# Retrieved data for 08, 2017
# Retrieved data for 09, 2017
# Retrieved data for 10, 2017
# Retrieved data for 11, 2017
# Retrieved data for 12, 2017
# Retrieved data for 01, 2018
# Retrieved data for 02, 2018
# Retrieved data for 03, 2018
# Retrieved data for 04, 2018
# Retrieved data for 05, 2018
# Retrieved data for 06, 2018
# Retrieved data for 07, 2018
# Retrieved data for 08, 2018
# Retrieved data for 09, 2018
# Retrieved data for 10, 2018
# Retrieved data for 11, 2018
# Retrieved data for 12, 2018
# Retrieved data for 01, 2019
# Retrieved data for 02, 2019
# Retrieved data for 03, 2019
# Retrieved data for 04, 2019
# Retrieved data for 05, 2019
# Retrieved data for 06, 2019
# Retrieved data for 07, 2019
# Retrieved data for 08, 2019
# Retrieved data for 09, 2019
# Retrieved data for 10, 2019
# Retrieved data for 11, 2019
# Retrieved data for 12, 2019
# Retrieved data for 01, 2020
# Retrieved data for 02, 2020
# Retrieved data for 03, 2020
# Retrieved data for 04, 2020
# Retrieved data for 05, 2020
# Retrieved data for 06, 2020
# Retrieved data for 07, 2020
# Retrieved data for 08, 2020
# Retrieved data for 09, 2020
# Retrieved data for 10, 2020
# Retrieved data for 11, 2020
